# %% [markdown]
# # Prova Modello TadGAN

# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf 

import matplotlib.pyplot as plt

from TadGan import *

# %%
tadgan = TadGan()
# Out:
# Parametri            | Valore
# -------------------- | --------
# Input shape          | (750, 3)
# Latent shape         | (150, 1)
# Gradient penalty     | 10
# Critic iterations    | 5
# Encoder LSTM units   | 100
# Decoder LSTM units   | 100
# Critic X CNN blocks  | 4
# Critic X CNN filters | 64
# Dropout              | 0.2
# ######################
# Model: "Encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 750, 3)]          0
#
#  bidirectional (Bidirection  (None, 750, 200)          83200
#  al)
#
#  flatten (Flatten)           (None, 150000)            0
#
#  dense (Dense)               (None, 150)               22500150
#
#  reshape (Reshape)           (None, 150, 1)            0
#
# ...
# Total params: 22583350 (86.15 MB)
# Trainable params: 22583350 (86.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
tadgan.summary()
# Out:
# Model: "tad_gan"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Encoder (Functional)        (None, 150, 1)            22583350
#
#  Decoder (Functional)        (None, 750, 3)            379628
#
#  Critic_X (Functional)       (None, 1)                 109633
#
#  Critic_Z (Functional)       (None, 1)                 45451
#
# ...
# Total params: 23118062 (88.19 MB)
# Trainable params: 23118062 (88.19 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
